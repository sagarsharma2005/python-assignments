# %%
#1) Convert a series of date-strings to a timeseries?

import pandas as pd

dates = ["2026-01-10", "2026-02-15", "2026-03-20"]

ts = pd.to_datetime(dates)

print(ts)
# Out:
# DatetimeIndex(['2026-01-10', '2026-02-15', '2026-03-20'], dtype='datetime64[us]', freq=None)

# %%
#2)Create two DataFrames, df1 and df2, with a common column (e.g., 'ID'). 

#>Perform an inner merge on this common column and display the resulting DataFrame.
#>Perform a left join of df1 and df2 on the 'ID' column. Explain how missing values are handled in the resulting DataFrame. Right Join and Index-Based Join.
#>Perform a right join using pd.merge() on a common column, then perform a join using df.join() based on the index. Compare the results. Merging with Multiple Keys.


import pandas as pd

df1 = pd.DataFrame({
    "ID": [1, 2, 3, 4],
    "Name": ["Sagar", "Rahul", "Aman", "Vikas"],
    "Class": ["BTech", "BCA", "BBA", "BCom"]
})

df2 = pd.DataFrame({
    "ID": [2, 3, 4, 5],
    "Marks": [85, 90, 78, 88],
    "Grade": ["B", "A", "C", "B"]
})

print("DataFrame 1")
print(df1)

print("DataFrame 2")
print(df2)

print("Inner Merge")
inner_merge = pd.merge(df1, df2, on="ID", how="inner")
print(inner_merge)

print("Left Join")
left_join = pd.merge(df1, df2, on="ID", how="left")
print(left_join)

print("Right Join")
right_join = pd.merge(df1, df2, on="ID", how="right")
print(right_join)

print("Index Based Join")
df1_index = df1.set_index("ID")
df2_index = df2.set_index("ID")

index_join = df1_index.join(df2_index, how="inner")
print(index_join)

print("Merging With Multiple Keys")
df3 = pd.DataFrame({
    "ID": [1, 2, 3],
    "Subject": ["Python", "DBMS", "Python"],
    "Name": ["Sagar", "Rahul", "Aman"]
})

df4 = pd.DataFrame({
    "ID": [1, 2, 3],
    "Subject": ["Python", "DBMS", "Java"],
    "Marks": [90, 85, 80]
})

multi_key_merge = pd.merge(df3, df4, on=["ID", "Subject"], how="inner")
print(multi_key_merge)
# Out:
# DataFrame 1
#    ID   Name  Class
# 0   1  Sagar  BTech
# 1   2  Rahul    BCA
# 2   3   Aman    BBA
# 3   4  Vikas   BCom
# DataFrame 2
#    ID  Marks Grade
# 0   2     85     B
# 1   3     90     A
# 2   4     78     C
# 3   5     88     B
# Inner Merge
#    ID   Name Class  Marks Grade
# 0   2  Rahul   BCA     85     B
# 1   3   Aman   BBA     90     A
# 2   4  Vikas  BCom     78     C
# Left Join
#    ID   Name  Class  Marks Grade
# 0   1  Sagar  BTech    NaN   NaN
# 1   2  Rahul    BCA   85.0     B
# 2   3   Aman    BBA   90.0     A
# 3   4  Vikas   BCom   78.0     C
# Right Join
#    ID   Name Class  Marks Grade
# 0   2  Rahul   BCA     85     B
# 1   3   Aman   BBA     90     A
# 2   4  Vikas  BCom     78     C
# 3   5    NaN   NaN     88     B
# Index Based Join
#      Name Class  Marks Grade
# ID
# 2   Rahul   BCA     85     B
# 3    Aman   BBA     90     A
# 4   Vikas  BCom     78     C
# Merging With Multiple Keys
#    ID Subject   Name  Marks
# 0   1  Python  Sagar     90
# 1   2    DBMS  Rahul     85

# %%
#3) Create three DataFrames. Vertically concatenate two of them using pd.concat(), then merge the resulting DataFrame with the third DataFrame on a common key. T Understand join() vs. merge().



import pandas as pd

df1 = pd.DataFrame({
    "ID": [1, 2],
    "Name": ["Sagar", "Rahul"]
})

df2 = pd.DataFrame({
    "ID": [3, 4],
    "Name": ["Aman", "Vikas"]
})

df3 = pd.DataFrame({
    "ID": [1, 2, 3, 4],
    "Marks": [85, 90, 78, 88]
})

combined = pd.concat([df1, df2])

print("Concatenated DataFrame")
print(combined)

result = pd.merge(combined, df3, on="ID")

print("Merged DataFrame")
print(result)
# Out:
# Concatenated DataFrame
#    ID   Name
# 0   1  Sagar
# 1   2  Rahul
# 0   3   Aman
# 1   4  Vikas
# Merged DataFrame
#    ID   Name  Marks
# 0   1  Sagar     85
# 1   2  Rahul     90
# 2   3   Aman     78
# 3   4  Vikas     88

# %%
#Also Explain the primary differences between df.join() and pd.merge(),

import pandas as pd

df1 = pd.DataFrame({
    "Name": ["Sagar", "Rahul"]
}, index=[1, 2])

df2 = pd.DataFrame({
    "Marks": [85, 90]
}, index=[1, 2])

print(df1.join(df2))

#-------------------------------------------------------------------------------

import pandas as pd

df1 = pd.DataFrame({
    "ID": [1, 2],
    "Name": ["Sagar", "Rahul"]
})

df2 = pd.DataFrame({
    "ID": [1, 2],
    "Marks": [85, 90]
})

print(pd.merge(df1, df2, on="ID"))
# Out:
#     Name  Marks
# 1  Sagar     85
# 2  Rahul     90
#    ID   Name  Marks
# 0   1  Sagar     85
# 1   2  Rahul     90
